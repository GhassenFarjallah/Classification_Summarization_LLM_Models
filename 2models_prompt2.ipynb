# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# Load the h2o-danube3-4b-chat model
model_name_h2o = "h2oai/h2o-danube3-4b-chat"
tokenizer_h2o = AutoTokenizer.from_pretrained(model_name_h2o)
model_h2o = AutoModelForCausalLM.from_pretrained(model_name_h2o)

# Create a text generation pipeline
pipe_h2o = pipeline("text-generation", model=model_h2o, tokenizer=tokenizer_h2o)

# Function to generate a single-paragraph summary
def generate_summary_h2o(input_text, prompt="Analyze the email and provide a detailed paragraph describing its purpose, key ideas, and recommendations:"):
    """
    Generates a single-paragraph summary based on the given input text.

    Args:
        input_text (str): The input text (e.g., an email).
        prompt (str): The task prompt to guide the model.

    Returns:
        str: The generated single-paragraph summary.
    """
    # Build the complete prompt
    full_prompt = f"{prompt}\n\n{input_text}\n\n### Paragraph Summary:"

    try:
        # Generate text using the pipeline
        result = pipe_h2o(
            full_prompt,
            max_new_tokens=150,  # Adjust length for a concise paragraph
            num_return_sequences=1,
            do_sample=True,
            temperature=0.7,
        )
        generated_text = result[0]["generated_text"]

        # Extract only the part after '### Paragraph Summary:'
        if "### Paragraph Summary:" in generated_text:
            summary = generated_text.split("### Paragraph Summary:")[1].strip()
        else:
            summary = generated_text.strip()  # Fallback if no delimiter is found

        # Clean up any repeated content or extra text
        if "Message-ID" in summary:
            summary = summary.split("Message-ID")[0].strip()

        return summary
    except Exception as e:
        return f"Error during generation: {e}"

# Example usage
input_text = """
Message-ID: <15464986.1075855378456.JavaMail.evans@thyme>
Date: Fri, 4 May 2001 13:51:00 -0700 (PDT)
From: phillip.allen@enron.com
To: john.lavorato@enron.com
Subject: Re:
Mime-Version: 1.0
Content-Type: text/plain; charset=us-ascii
Content-Transfer-Encoding: 7bit
X-From: Phillip K Allen
X-To: John J Lavorato <John J Lavorato/ENRON@enronXgate@ENRON>
X-cc:
X-bcc:
X-Folder: \Phillip_Allen_Jan2002_1\Allen, Phillip K.'Sent Mail
X-Origin: Allen-P
X-FileName: pallen (Non-Privileged).pst

Traveling to have a business meeting takes the fun out of the trip. Especially if you have to prepare a presentation. I would suggest holding the business plan meetings here then take a trip without any formal business meetings. I would even try and get some honest opinions on whether a trip is even desired or necessary.

As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not. Too often the presenter speaks and the others are quiet just waiting for their turn. The meetings might be better if held in a round table discussion format.

My suggestion for where to go is Austin. Play golf and rent a ski boat and jet ski's. Flying somewhere takes too much time.
"""

# Generate the paragraph summary
paragraph_summary = generate_summary_h2o(input_text)

# Print only the summary
print(paragraph_summary)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.70k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.79M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/484 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/18.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch
import warnings

# Set random seed for reproducibility
torch.random.manual_seed(0)

# Load the model and tokenizer
model_name_phi3 = "microsoft/Phi-3-mini-128k-instruct"
model_phi3 = AutoModelForCausalLM.from_pretrained(model_name_phi3, torch_dtype="auto", trust_remote_code=True).to("cuda")
tokenizer_phi3 = AutoTokenizer.from_pretrained(model_name_phi3)

# Disable parallel tokenizer warnings
warnings.filterwarnings("ignore", category=UserWarning)

# Define the pipeline
pipe_phi3 = pipeline(
    "text-generation",
    model=model_phi3,
    tokenizer=tokenizer_phi3,
)
# Function to generate a paragraph-style summary
def generate_summary_phi3(input_text, prompt="Analyze the email and provide a detailed paragraph describing its purpose, key ideas, and recommendations:"):
    """
    Generates a paragraph-style summary based on the given input text.

    Args:
        input_text (str): The input text (e.g., an email).
        prompt (str): The task prompt to guide the model.

    Returns:
        str: The generated paragraph-style summary or description.
    """
    # Add a clear delimiter for the model to follow
    full_prompt = f"{prompt}\n\n{input_text}\n\n### Paragraph Summary:"

    try:
        # Generate text using the pipeline
        result = pipe_phi3(
            full_prompt,
            max_new_tokens=200,
            num_return_sequences=1,
            do_sample=True,
            temperature=0.7,
        )
        generated_text = result[0]["generated_text"]

        # Extract only the part after '### Paragraph Summary:'
        if "### Paragraph Summary:" in generated_text:
            summary = generated_text.split("### Paragraph Summary:")[1].strip()
        else:
            summary = generated_text.strip()  # Fallback if no delimiter is found

        # Clean up: remove any part that repeats the input email
        if "Email:" in summary:
            summary = summary.split("Email:")[0].strip()

        return summary
    except Exception as e:
        return f"Error during generation: {e}"

# Example usage
input_text = """
Message-ID: <15464986.1075855378456.JavaMail.evans@thyme>
Date: Fri, 4 May 2001 13:51:00 -0700 (PDT)
From: phillip.allen@enron.com
To: john.lavorato@enron.com
Subject: Re:
Mime-Version: 1.0
Content-Type: text/plain; charset=us-ascii
Content-Transfer-Encoding: 7bit
X-From: Phillip K Allen
X-To: John J Lavorato <John J Lavorato/ENRON@enronXgate@ENRON>
X-cc:
X-bcc:
X-Folder: \Phillip_Allen_Jan2002_1\Allen, Phillip K.'Sent Mail
X-Origin: Allen-P
X-FileName: pallen (Non-Privileged).pst

Traveling to have a business meeting takes the fun out of the trip. Especially if you have to prepare a presentation. I would suggest holding the business plan meetings here then take a trip without any formal business meetings. I would even try and get some honest opinions on whether a trip is even desired or necessary.

As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not. Too often the presenter speaks and the others are quiet just waiting for their turn. The meetings might be better if held in a round table discussion format.

My suggestion for where to go is Austin. Play golf and rent a ski boat and jet ski's. Flying somewhere takes too much time.
"""

# Generate the paragraph-style summary
description = generate_summary_phi3(input_text)

# Print only the summary
print(description)
# Out:
# config.json:   0%|          | 0.00/3.48k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.a90b62ae09941edff87a90ced39ba5807e6b2ade.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.a90b62ae09941edff87a90ced39ba5807e6b2ade.modeling_phi3:Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# `get_max_cache()` is deprecated for all Cache classes. Use `get_max_cache_shape()` instead. Calling `get_max_cache()` will raise error from v4.48
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.a90b62ae09941edff87a90ced39ba5807e6b2ade.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
# This email, sent by Phillip K. Allen to John J. Lavorato, discusses the downsides of combining business travel with presentations. Allen suggests that business meetings would be more productive if held in Austin, where attendees could engage in round-table discussions rather than passive listening. He humorously recommends leisure activities such as golf and water sports in lieu of flying, citing the excessive time these flights take.
#
#
# ## Instruction 2

# %%
import pandas as pd
from google.colab import drive
# **Étape 1 : Connecter Google Drive et Charger le fichier**
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/emails_final1.csv'  # Remplacez par votre chemin réel
data = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
data['resume_h2o-2'] = data['message'].apply(generate_summary_h2o)

# %%
data2['resume_h2o_2'].head()
# Out:
# 0    0 The email is from Phillip Allen to Tim Belde...
# 1    Phillip Allen suggests holding business meetin...
# 2    Phillip Allen sends a test email to Leah Van A...
# 3    Phillip Allen requests a detailed schedule wit...
# 4    Phillip Allen sends a message about a meeting ...
# Name: resume_h2o_2, dtype: object

# %%
data['resume_phi3_2'] = data['message'].apply(generate_summary_phi3)

# %%
data2['resume_phi3_2'].head()

# %%
data2
# Out:
#                         file  \
# 0      allen-p/_sent_mail/1.
# 1     allen-p/_sent_mail/10.
# 2    allen-p/_sent_mail/100.
# 3   allen-p/_sent_mail/1000.
# 4   allen-p/_sent_mail/1001.
# ..                       ...
# 95   allen-p/_sent_mail/180.
# 96   allen-p/_sent_mail/181.
# 97   allen-p/_sent_mail/182.
# 98   allen-p/_sent_mail/183.
# 99   allen-p/_sent_mail/184.
#
#                                               message  \
# 0   Message-ID: <18782981.1075855378110.JavaMail.e...
# 1   Message-ID: <15464986.1075855378456.JavaMail.e...
# 2   Message-ID: <24216240.1075855687451.JavaMail.e...
# 3   Message-ID: <13505866.1075863688222.JavaMail.e...
# 4   Message-ID: <30922949.1075863688243.JavaMail.e...
# ..                                                ...
# 95  Message-ID: <29919154.1075855689201.JavaMail.e...
# 96  Message-ID: <4511963.1075855689223.JavaMail.ev...
# 97  Message-ID: <33111317.1075855689245.JavaMail.e...
# 98  Message-ID: <1665326.1075855689266.JavaMail.ev...
# 99  Message-ID: <4752513.1075855689288.JavaMail.ev...
#
#                                           resume_phi3  \
# 0   The email, sent by Phillip Allen to Tim Belden...
# 1   The purpose of this email, sent by Phillip K A...
# 2   The email, sent by Phillip Allen to Leah Van A...
# 3   The email, sent by Phillip Allen to Randall Ga...
# 4   The email, sent by Phillip Allen to Greg Piper...
# ..                                                ...
# 95  The email from Phillip Allen to Mac D. Hargrov...
# 96  The email, sent by Phillip Allen from Enron to...
# 97  This email, sent by Phillip Allen of Enron to ...
# 98  The email, sent by Phillip Allen to pallen70@h...
# 99  The email, sent by Phillip Allen of Enron and ...
#
#                                            resume_h2o  \
# 0   The email is a message from Phillip Allen to T...
# 1   The sender, Phillip Allen, suggests that inste...
# 2   The email from Phillip Allen to Leah Van Arsda...
# 3   Phillip Allen requests a schedule detailing th...
# 4   - Phillip Allen sends a message about a Tuesda...
# ..                                                ...
# 95  Phillip Allen, from Enron, sends a message to ...
# 96  The email from "Lucy Gonzalez" to Phillip Alle...
# 97  This email is from Phillip Allen to pallen70@h...
# 98  A message from Phillip Allen at Enron to Phyll...
# 99  Phillip Allen, from Enron, responds to an emai...
#
#                                         resume_phi3_2  \
# 0   L'email envoyé par Phillip Allen à Tim Belden ...
# 1   Dans un autre email, Phillip Allen propose à J...
# 2    Un troisième email adressé à Leah Van Arsdall...
# 3   Dans un email à Randall Gay (23 octobre 2000),...
# 4    Un autre message à Greg Piper fait suite à un...
# ..                                                ...
# 95  The email from Phillip Allen to Mac D. Hargrov...
# 96  The email, sent by Phillip Allen from Enron to...
# 97  This email, sent by Phillip Allen of Enron to ...
# 98  The email, sent by Phillip Allen to pallen70@h...
# 99  The email, sent by Phillip Allen of Enron on A...
#
#                                          resume_h2o_2  \
# 0   0 The email is from Phillip Allen to Tim Belde...
# 1   Phillip Allen suggests holding business meetin...
# 2   Phillip Allen sends a test email to Leah Van A...
# 3   Phillip Allen requests a detailed schedule wit...
# 4   Phillip Allen sends a message about a meeting ...
# ..                                                ...
# 95  Phillip Allen, from Enron, sends a message to ...
# 96  The email from Lucy Gonzalez to Phillip Allen ...
# 97  This email is from Phillip Allen to pallen70@h...
# 98  A message from Phillip Allen at Enron to Phyll...
# 99  Phillip Allen, from Enron, responds to an emai...
#
#                                                resume
# 0   Prévision partagée (14 mai 2001) – Phillip All...
# 1   Suggestion pour un voyage d'affaires (4 mai 20...
# 2   Test réussi (18 octobre 2000) – Phillip Allen ...
# 3   Demande de détails sur les salaires et niveaux...
# 4   Proposition de réunion (31 août 2000) – Philli...
# ..                                                ...
# 95  I think crude price are undervalued by the tun...
# 96  Summarize the following email by focusing on t...
# 97  "Lucy Gonzalez": "The a/c I bought today for #...
# 98  Summarize the following email by focusing on t...
# 99  I checked into exercising options with Smith B...
#
# [100 rows x 7 columns]

# %%
for i in data['resume_h2o']:
   print(i)
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@0
# The email is a message from Phillip Allen to Tim Belden containing a text-based forecast. The message details the sender's name, the date, and the subject matter of the email, which is the forecast. The email is a part of a series of communications within an EnronXGate folder, indicating that it might be related to Enron's business operations or activities. The message is not encrypted and is in plain text. The email also includes a header that specifies the sender, the recipient, and the email's origin. The email was sent on May 14, 2001, at 4:39 PM, and the sender's email address is phillip
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@1
# The sender, Phillip Allen, suggests that instead of traveling for business meetings, they should be held in Austin, Texas, to make the trip more enjoyable. He proposes a more interactive meeting format with round table discussions, and he personally recommends Austin for its recreational activities and shorter travel time. The email also includes a reminder to John Lavorato about a previous meeting and a suggestion to discuss the business plan rather than just present it.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@2
# The email from Phillip Allen to Leah Van Arsdall is a test message indicating that the test was successful. The email contains only the message body and does not include headers or other metadata.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@3
# Phillip Allen requests a schedule detailing the salary and position of each person in the scheduling group, as well as Randy Gay's thoughts on any necessary changes, including Patti S. Phillip Allen needs this information immediately.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@4
# - Phillip Allen sends a message about a Tuesday meeting at 11:45.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@5
# Phillip Allen from Enron suggests either Tuesday or Thursday next week for a meeting.
#
# ---
#
# This summary captures the essence of the email, providing a brief and clear message for a meeting.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@6
# Phillip Allen, from the email address phillip.allen@enron.com, is requesting that the distribution list containing the email recipients be expanded to include the following individuals: Mike Grigsby (mike.grigsby@enron.com), Keith Holst (kholst@enron.com), Monique Sanchez, Frank Ermis, and John Lavorato. The email also mentions that the distribution list should be cc'd to all the recipients. Allen expresses gratitude for the help provided. The email is part of a larger collection of correspondence and is being sent from a specific folder named pallen.nsf. The origin of the email is identified as
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@7
# The email is a message sent by Phillip Allen from his email address phillip.allen@enron.com to Joyce Teixeira at her email address joyce.teixeira@enron.com. The message is in the MIME format with a MIME version of 1.0. The email is written in plain text and uses the charset of US-ASCII and the Content-Transfer-Encoding of 7bit. The email is a part of the Allen-P folder and is titled "pallen.nsf". There is an attached X-FileName of "pallen.nsf". The email is about scheduling a phone call between 10:00
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@8
# Phillip Allen sent an email to Mark Scott, requesting access to a network login with the credentials "pallen pw: ke9davis". Allen clarifies that these credentials are not necessary according to the ISP. He also provides details about the static IP address, subnet mask, gateway, DNS server, and company/registration code.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@9
# Phillip Allen from Enron is seeking a fixed price forward gas deal for a microturbine power generation deal with a national accounts customer. The microturbines will generate electricity for the customer, and the deal must have a limited or no-risk forward gas price. Buckner from Honeywell is discussing the gas requirements, which vary based on the number of microturbines installed. The gas will be consumed during peak electric periods from May to September. Buckner is seeking a detailed breakout of commodity and transport costs for both firm and interruptible gas. Buckner also mentions the potential for additional questions and assures that this is a real deal.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@10
# Phillip Allen from Enron Energy Services has forwarded Buckner's request to Zarin Imam at EES regarding fixed forward or other Collar floor gas price terms for delivered gas behind San Diego. Allen has provided Imam's contact information (phone number: 713-853-7107) for further communication.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@11
# In this email, Phillip Allen from Enron requests Lucy to open the provided rentroll files and save them in the specified "rentroll" folder. To avoid misplacing the files, he instructs her to follow these steps:
# 1. Click on "Save As"
# 2. Click on the dropdown triangle under "Save in:"
# 3. Click on the "C:" drive
# 4. Choose the appropriate folder
# 5. Click on "Save."
#
# Phillip Allen
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@12
# The email chain discusses the need to document the requirements for consolidated physical/financial positions and transport trade capture. The sender, Phillip K Allen, outlines the issues and tasks that need to be addressed, emphasizing the importance of a single set of requirements to achieve the project's goals. Richard Burchfield, another team member, agrees with Allen's assessment and suggests focusing on defining a desired layout for the consolidated position screen. The email also includes a list of tasks and requests that need to be considered for the project. The sender, Allan Severude, highlights the need for a single point of contact from the trading group and the importance of determining which requests fall within the project scope. The team is also
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@13
# This email is a consolidated position issues and to-do list from Richard Burchfield and Allan Severude from Enron. The main points of discussion include:
#
# 1. The need for a single set of requirements for documenting the requirements for consolidated physical/financial positions and transport trade capture.
# 2. The difficulty and time-consuming nature of creating a dynamic consolidated position screen.
# 3. The necessity of designing a desired layout for the consolidated position screen, which will help create a plan that can be measured.
# 4. The importance of coming to a consensus with traders on the presentation of the consolidated position screen.
# 5. The need for a single point of contact from the trading
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@14
# Phillip Allen from Enron is sending an email to David Delainey with attached names of West Desk members categorized by origination side, which is sparse, and also includes a filename.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@15
# The email is a response from Phillip Allen to Paula Harris, confirming that 35 million is acceptable for the 2001 Margin Plan.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@16
# The email is a meeting invitation from Phillip K Allen to various Enron employees, including Ina Rangel, regarding a meeting on Var, Reporting and Resources. The meeting is scheduled for Wednesday, October 11th, from 2:30 pm to 3:30 pm in the EB30C1 location. Phillip Allen requests anyone with questions or conflicts to contact him.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@17
# The email is from Phillip Allen, with the email address Phillip.Allen@enron.com, to Tim Heizenrader, with the email address Tim.Heizenrader@enron.com. The subject of the email is "". The email is dated May 4, 2001, at 11:26:00 -0700 (PDT). The email is formatted in MIME with the version set to 1.0. The
# Content-Type is set to "text/plain; charset=us-ascii". The Content-Transfer-Encoding is set to 7bit. The email is addressed to Tim Heizenrad
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@18
# The sender, Phillip K Allen (phillip.allen@enron.com), is forwarding an email from George Richards (cbpres@austin.rr.com) to "Phillip Allen" (pallen@enron.com) and "Larry Lewter" (retwell@mail.sanmarcos.net). The email discusses demographics and development opportunities related to the Westgate property. George Richards provides demographic information and highlights the potential for high rents at the Westgate site. He also mentions an opportunity to secure land for a new development project, with an equity requirement of $300,000. The deadline for this opportunity is
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@19
# The email is a message from Phillip K Allen to Ina Rangel, with recipients from Enron. It's about a meeting scheduled for Tuesday, Oct. 10th at 4:00pm in EB3270, regarding Storage Strategies in the West. The message is forwarded and cc-ed to various Enron contacts, including Nancy Hall, Paul Lucci, Tyrell Harrison, and others. Allen requests them to mark their calendars for the meeting.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@20
# The email, sent on October 3, 2000, contains a message from Phillip Allen to Brenda Stone. The message is identified by the
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@21
# The sender, Phillip Allen, sends a message to Steve Touchstone, expressing a preference for a CPA recommended by Fletch and admitting to still doing their own taxes. The email is sent from Allen's work account.
#
# ---
#
# **EMAIL RECAP:**
#
# Subject: RE: Not business related...
#
# From: Phillip.Allen@enron.com
# To: stouchstone@natsource.com
#
# Date: October 3, 2000
#
# Phillip Allen, from Allen-P, shares his opinion that Fletch's CPA is good. Despite this, Allen admits to managing his own taxes. The email is
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@22
# Phillip Allen requests Brenda Stone to use the second check as the October payment, as he has a copy of the original deal and is willing to send it via fax if needed. He also mentions he has saved the first check in his Notes Folders under the name "pallen.nsf".
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@23
# In a 28th September 2000 email, Phillip Allen, a representative from Enron, raises concerns about potential manipulation of the El Paso San Juan monthly index. He notes an unusual series of trades where a single buyer paid above market prices for San Juan gas on the 26th and 27th of September. These trades are at odds with the associated financial swaps and seem to bypass lower offers. Allen also provides a detailed spreadsheet of trades from various sources, including Enron Online, direct phone conversations, and brokerage firms, to illustrate the inconsistency between physical and financial trades. He emphasizes the need for reliable and accurate indices for En
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@24
# Phillip Allen, from Enron, is concerned about potential manipulation in the
# El Paso San Juan monthly index. A single buyer, who paid above market prices
# ($4.70-$4.80), entered the marketplace on September 26 and 27, and distorted
# the index by paying higher prices than the associated financial swaps.
# Enron has compiled a list of financial and physical trades executed from
# September 25 to September 27, which show that the high physical prices on
# the 26th and 27th are much greater than the high financial trades on those
# days. The spread relationship
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@25
# The email communication between Phillip Allen and George Richards discusses investment strategies for a new real estate development project. The structure of the investment is outlined, with the general partner responsible for construction and landowner loans. The text also mentions the use of professional fees and land loans, as well as a phasing strategy for the construction of the property. The email concludes with a request for further discussion on the subject.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@26
# The email is a detailed response to an earlier message from Phillip Allen regarding the investment structure for a development project. George Richards, the President of Creekside Builders, LLC, provides a comprehensive overview of the investment structure, including the role of the limited partnership, land ownership and loans, use of initial investment, early land costs, equity at improvement loans, lot improvement loan, total equity, engineering and architectural design costs, phasing, construction loans, disbursements, reporting (internet-based), bookkeeping procedures, investor input, and Creekside Builders' procedures for dealing with subs, vendors, and professionals. He also mentions the existence of pre-selected professionals, subs, and vendors.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@27
# The email includes several meeting and status update reminders for employees of Enron. These reminders include:
#
# 1. Rescheduling of a meeting: The initial meeting has been rescheduled to 10/03/2000 02:30 PM and will repeat starting on 09/27/2000 02:00 PM.
#
# 2. Meeting details: These meetings repeat on specific dates and times, and the attendees are listed.
#
# 3. Meeting notes: The email provides brief descriptions of each meeting, including the date, time, and room location.
#
# 4. Status updates: Some of the attendees have been assigned
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@28
# Phillip Allen, from Enron, is writing to Reagan regarding a construction project. They have revised the unit mix to include 1 bedrooms and reduced the number of buildings to 12. Kipp Flores is working on the construction drawings, and Phillip is seeking FHA financing. Once the drawings are complete, a revised bid will be sent. Phillip appreciates Enron's competitive bid and the local presence of the firm.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@29
# Cindy Cicchetti,
#
# Please reschedule the Gas Trading Vision meeting due to the Nymex expiration occurring during the planned time frame.
#
# Best,
# Phillip K Allen
#
# ---
#
# ---
#
# I apologize for the confusion in my previous message. I misunderstood the original email and thought it was from Phillip K Allen. It appears that my previous message was addressed to Cindy Cicchetti, and the text I provided was actually part of an earlier conversation with Phillip K Allen.
#
# To clarify, the message from Phillip K Allen was sent to Cindy Cicchetti, and it was not part of the original
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@30
# A meeting has been scheduled by Cindy Cicchetti on September 27th, 2000, from 11:30 AM to 12:30 PM in Room EB2556. The purpose of the meeting is to discuss the Gas Trading Vision. This event will be repeated every week on the same schedule, starting from the date of the initial meeting. The list of attendees includes Phillip K Allen, Hunter S Shively, Scott Mills, Allan Severude, Jeffrey C Gossett, Colleen Sullivan, Russ Severson, Jayant Krishnaswamy, and Russell Long, who are all employees of En
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@31
# The email is from Phillip Allen, addressed to Ina Rangel and several other recipients, including Cindy Cicchetti, Hunter Shively, Scott Mills, Allan Severude, Russ Severson, Fletcher Sturm, and Scott Neal. The email serves as a reminder about an upcoming meeting on Thursday, 9/28, from 3:00 to 4:00 PM, in Room EB2537, with the purpose of discussing the Gas Physical/Financial Position. The message was forwarded by Phillip K Allen.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@32
# Phillip K Allen addresses Jeff and asks about the finalization of a transaction. It is uncertain if the closing will take place today due to the lack of binding nature of the agreement provided. Phillip Allen is unsure about the validity of the agreement and seeks clarification. He contacts his closing documents to understand his position and will deal with the situation as best as possible. Phillip Allen is available from 12 PM onwards if Jeff needs to contact him regarding the closing. He does not want to delay or create more work and does not want to appear rude.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@33
# The email is from Phillip Allen to Christopher Calger, discussing the latest updates on PG&E. They have been having positive discussions regarding EOL, and Phillip requests a call when Christopher can make it.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@34
# A rescheduled meeting with Richard Burchfield/HOU/ECT is taking place on September 28, 2000, from 01:00 PM to 02:00 PM. The meeting, originally scheduled for September 28, 2000, was rescheduled to a new time. The meeting details include the attendees and the subject matter: Gas Physical/Financial Positions. The meeting will be held in Room 2537.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@35
# The email is a reminder for an upcoming meeting regarding gas physical/financial positions, to be held on September 27, 2000, from 1:00 PM to 2:00 PM in Room 2537. The meeting is repeated, starting on the same date, and the schedule is subject to change if the date falls on a weekend. The email is from Phillip Allen, an Enron employee, and is directed to Ina Rangel.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@36
# A message was sent from Phillip Allen to Greg, wishing him a happy birthday and inviting him to call. The email was sent on September 25, 2000, and the sender used the subject line "Happy B-day." The message was received in an email with the Mime-Version set to 1.0 and the Content-Type set to text/plain with a character set of us-ascii. The email was encoded using 7bit and had the X-From header set to Phillip K Allen, the X-To header set to muller@thedoghousemail.com, the CC header set to an empty string, and the BCC header
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@37
# Phillip Allen requests Kathy Moore to forward the guest password for gas daily to Mike Grigsby at 37031, as he will be out of the office on Friday. Phillip will also be out of the office on Friday.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@38
# The email from Phillip Allen to John Lavorato was sent on September 20, 2000, at 08:06:00 -0700 (PDT). The MIME-Version is 1.0, and the Content-Type is text/plain; charset=us-ascii. The email is in 7bit Content-Transfer-Encoding. The email includes a message from Phillip K Allen, addressed to John J Lavorato, cc'ed to  and bcc'ed to the X-Folder: \Phillip_Allen_Dec2000\Notes Folders\'sent mail. The content of the
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@39
# Phillip Allen is writing to James Steffes inquiring about the availability of a conference call or weekly meeting regarding the regulatory issues in California this week. He asks to ensure that the gas desk is included in the discussion.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@40
# Phillip Allen from Enron is seeking clarification on the Westgate project's ownership structure, investment details, debt and improvement related matters, and the involvement of various legal entities. He also wants to understand the investment return, disbursement procedures, and reports to track expenses. The email also includes a list of questions about construction planning, investor involvement, and the relationship between Creekside Builders and the project.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@41
# Phillip Allen sends a revised proforma for the Westgate property in Austin to Larry Lewter, highlighting the potential profitability and risk-reward ratio of the project. The proforma shows a projected return of over 40% per year for three years, despite Austin's strong market and low-priced residential developments. The project has approved zoning and is expected to be fast-tracked, with many water treatment ordinances waived. The lot improvement costs are estimated based on a previous project in North Austin. The Lone Star gas line easement is not expected to affect sales significantly. The seller accepted The Lone Star Gas Company's offer on Thursday, and the property is
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@42
# In the email dated September 19, 2000, Phillip Allen from Enron shares sales figures from Reagan, highlighting the units sold at varying prices per square foot. He notes that the 1308/1308 model has the most data and appears similar to the units Allen is selling. Allen bids.70/sf higher than Reagan's units under construction, feeling it's justified due to competition. He is seeking George's opinion and mentions a follow-up email and phone call regarding Cherry Creek and the De Ville property bid rejection. Phillip Allen is also informed by Deborah Yates that the bid on De Ville property was rejected
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@43
# The email is from Phillip Allen at Enron, sent to jsmith@austintx.com, dated September 19, 2000, at 03:15:00 -0700 (PDT). The message, with a subject line that does not match the actual content, is a question about what is happening in Burnet. The email is a part of a folder labeled "Notes Folders'sent mail" and was sent to another folder named "pallen.nsf".
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@44
# Phillip Allen, a representative from ENRON, is reaching out to Jeff Smith due to a need for approval from Brenda Key Stone before selling a property in Burnet. Phillip requests to review the site plan and closing statements for the property as soon as possible.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@45
# A message from Phillip Allen, sent on September 13, 2000, at 6:02 AM, is addressed to Lucy. Allen requests an accurate rent roll and has faxed a copy of the file to be filled in on the computer or written manually. He will then input the correct amounts.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@46
# Phillip Allen informs Brenda Stone that he mailed check #1178 on August 28th to cover the September payment. He will send another check if the first one is not received. Phillip assures Brenda that he will address the site plan concerns and is in the process of locating the amortization schedule to send to her.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@47
# Phillip Allen, an employee at Enron, sent an email to Lucy regarding their financial transactions for August. Phillip noticed that Lucy had written fewer checks and spent more money on materials and less on labor compared to previous months. He then proceeded to ask Lucy about certain details on her bank statement for August, including the purpose of specific checks and overtime payments. Phillip requested Lucy to provide the necessary information to support these questions.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@48
# The email is from Phillip K Allen to Paul T Lucci, Kenneth Shulklapper, and possibly others, requesting a contact list for the mid-market. Michael Etringer has already prepared a list, which Phillip needs to be filled out. The goal is to avoid overlap among team members.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@49
# An email message with the subject line "Mime-Version: 1.0" was sent on September 12, 2000, at 12:27 AM, from Phillip K Allen at Enron, to moshuffle@hotmail.com. The email is in plain text format with a.nsf file attached. The sender's address is phillip.allen@enron.com. The email is part of a folder named "Notes Folders\sent mail" and does not have any Cc or Bcc recipients. The email is addressed to moshuffle@hotmail.com and can be accessed through a URL provided by the sender.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@50
# The message is a forwarded email from Phillip K Allen, containing a forwarded email from Ina Rangel. The email is about scheduling a survey and it asks Phillip Allen about his computer type, PDA type, access permissions, address book responsibilities, shared calendar access, and distribution group usage. The sender also asks about Phillip Allen's normal work hours and if he will be out of the office in the near future.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@51
# The email from George Richards to Phillip Allen discusses a preliminary
# proforma for the Westgate property in Austin. The property is expected to
# produce a high return of over 40% per year over 3 years, given its strong
# Austin market and the introduction of a new, low-priced product. The project
# is in the "Smart Growth Corridor" area, which allows for fast-tracked
# approval and waived water treatment ordinances. The property is estimated
# to require a site plan and includes a fence and potential gated community.
# The seller has accepted an offer, with a 50% interest in the profits for
# Ph
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@52
# In this email, Phillip Allen is communicating with Jeff Smith about viewing the rent roll and potentially inspecting a property, Chelsea Villas. He plans to visit San Marcos over the weekend but is occupied with other commitments. Phillip requests information about the last sale of Chelsea Villas and asks Jeff to gather site plans for the Burnet deal to satisfy Brenda.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@53
# The email is from Phillip Allen to John Lavorato and is part of a series of messages related to energy benchmark reports. The message details changes in the transport positions for Socal and San Juan, resulting in a net selling position for San Juan. Allen explains that the report shows net selling because of a rollover adjustment, adding 800 shorts to San Juan and 200 longs to Socal. Before this adjustment, the company had bought 300 San Juan and sold 800 Socal. The email is part of a larger file titled "pallen.nsf" and is included in a specific folder.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@54
# This message is a response to a previous discussion thread regarding the "VaR by Curve" topic. The sender, Phillip K Allen, seeks clarification on the ranking of AECO basis in relation to other curves and the correlation between AECO and the NYMEX. The sender asks for an explanation of why AECO basis is low on the list and inquires about the mapping differences between AECO and NWPL. Additionally, the sender requests information on the correlation between AECO and NYMEX. The message is sent to Frank Hayden and includes a reference to a specific note folder.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@55
# In this email, Phillip Allen, from Enron, discusses the value of a potential deal involving the Sagewood property. He expresses surprise at Jeff Smith's request for payment and inquires about his role in brokering properties or contacts. Allen questions whether Smith's position is based on legal or ethical grounds and asks if they are considering developing the project from scratch. He states that he is not willing to pay more than 2.7 for Sagewood at this time.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@56
# A message was sent from Phillip K Allen to pallen70@hotmail.com, discussing the Sagewood Town Homes project. The sender (George Richards) mentions that the lot developer, Regan Lehman, is selling his units in the $180's, which would make an average square footage of 1233 at $73.80 per square foot. He believes that a 3-bedroom, 3.5 bath unit is preferred in the market and plans to call Phillip to discuss further.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@57
# The email is from George Richards to Phillip Allen, discussing a potential investment opportunity in a property in Austin. The property, called Westgate, has a preliminary proforma estimating a 40% return over 3 years. The project is expected to be approved quickly due to its location in Austin's Smart Growth Corridor and the waiving of some water treatment ordinances. The property has an estimated lot improvement cost based on a previous project. The seller has accepted an offer, and George plans to schedule a tour of the site. The email concludes with a request for Phillip to get back to George as soon as possible and mentions some recent setbacks George and his wife faced.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@58
# The email, sent by Phillip K Allen from Enron, is forwarded to pallen@enron.com with a cc to pallen70@hotmail.com and a bcc to itself. It refers to a file named "utility.xls" which is attached to the message. The email is a forwarded message from Lucy Gonzalez. The content of the email does not include the actual message but refers to the attachment. The email is part of a forwarded chain of emails, likely related to a discussion or collaboration on a project involving utilities.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@59
# The email is a reminder from Phillip K Allen to Ina Rangel to fill out a survey for the Executive Impact & Influence Program. The survey requires the input of immediate managers, direct reports, and peers/colleagues to provide feedback on the participant's management styles and practices. The survey must be completed by the deadline, and the participant's attendance may be canceled if insufficient feedback is received. The unique ID for the participant is provided, and assistance is available for technical issues. If you have any questions, contact Debbie Nowak or Christi Smith.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@60
# In an email dated September 6, 2000, Phillip Allen, an employee at Enron, contacts Larry regarding the Sagewood townhomes and other potential development opportunities. Allen mentions stumbling upon other duplexes being sold on the same street for $182,000 each. He had previously spoken with Reagan Lehmann, who sold 22 units for $2 million, and was in the process of constructing more units. Allen inquires about the differences between the units and proposes a bid of $2.7 million, which would be $193,000 per duplex. Allen expresses interest in investing in a new project and requests
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@61
# - An urgent message from Phillip K. Allen to Ina Rangel and others, regarding accessing Outlook Web Access (OWA) to print a message.
# - The email provides a concise overview of the reasons for using OWA, including remote access to mailboxes and the ability to send and receive email even before the Outlook client is configured.
# - The email also explains how to access OWA through Internet Explorer, with some limitations compared to the Outlook client.
# - For any questions or concerns, users are directed to contact the Outlook 2000 question and answer Mailbox or the Resolution Center.
# - The email concludes with a thank you from the Outlook 20
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@62
# Phillip Allen from Enron schedules a meeting with Jean Mrha at 3:30 PM tomorrow.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@63
# - The email exchange discusses the significant impact of the Internet economy on electricity demand, with server farms and technology companies causing substantial load growth.
# - Phyllip Allen, the sender, warns about the potential for a power crisis in the future due to the high electricity consumption of these data centers.
# - The email highlights the concerns of local utilities in Seattle, who are struggling to meet the increasing demand for electricity from these data centers.
# - The email also mentions the growth of the Internet data center industry in Seattle, with several companies constructing large facilities to house servers and networking equipment.
# - The utilities are facing challenges in accommodating the power requirements of these data centers, leading to potential capital expenditures and
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@64
# The email is a message sent by Phillip K Allen to Ina Rangel, who is likely a colleague or employee at Enron. Allen is requesting that Rangel pulls resumes and past performance reviews of two individuals, Tori K. and Martin Cuilla, from the HR department. The email includes the full content of the message, which is in plain text format and has been forwarded by Phillip K Allen.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@65
# The email is a response to a previous email and is from Phillip Allen to John Lavorato. The content of the email is not explicitly clear from the message header, but it seems to be asking for the resumes of someone.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@66
# In a business communication thread, Christi Smith requests the completion of a Team Selection form for the Executive Impact & Influence Program. Phillip Allen, who had provided some information, asks for the remaining details. Christi requests email addresses and phone numbers for team members to facilitate feedback and reminders. She emphasizes the importance of completing the form or providing the necessary information promptly. The thread also includes responses from both parties, with Christi confirming the receipt of the form and Phillip confirming the completion of the forms with the requested details.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@67
# An email from Phillip K Allen at Enron to Mark at Intelligence Press, dated 09/05/2000 at 01:29 PM, includes a spreadsheet detailing the company's September Socal trades. The email does not specify whether the trades are buys or sells.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@68
# This email is a forwarded message from Phillip K Allen to Mike Grigsby and Frank Ermis. It provides a forwarded document from Ray Niles titled "Price Caps.pdf". The email is dated September 1, 2000, and it is part of the Allen-P folder in the North America Corp. of Enron.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@69
# This email is a message from Phillip Allen, sent to Richard Redash at PIRA,
# asking him to compare his California production figures to those in the 2000
# California Gas Report, which shows 410. Phillip believes these numbers might
# only reflect what the two utilities receive, not the full production.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@70
# Phillip Allen from Enron requests that Cooper Richey grant access to the new West Power site to Jay Reitmeyer, an analyst from their group.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@71
# This email is a follow-up message from Phillip K. Allen to Christi L. Smith regarding the Team Selection Form for the Executive Impact & Influence Program. Phillip acknowledges the receipt of Christi's previous email and expresses gratitude for her prompt attention. He clarifies that although they have received the completed Team Selection form, they require additional information, specifically email addresses and phone numbers for each team member. Phillip requests the team members' email addresses to send them internet links and IDs for feedback collection, as well as to send automatic reminders via email. He also requests phone numbers for communication purposes. Phillip thanks Christi for her assistance and requests the complete Team Selection Excel spreadsheet or
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@72
# The email message is a request for a survey or information email regarding the Outlook migration process at Enron. The purpose of the survey is to gather individual user information to ensure a successful migration from Notes to Outlook. The survey includes questions about the user's login ID, extension, office location, computer type, presence of a Personal Digital Assistant (PDA), permission to access others' email/calendar, and whether others have permission to access theirs. It also asks about responsibility for updating address books and shared calendars, as well as access to distribution groups maintained by Messaging. The email also seeks information about the user's normal work hours, any upcoming absences, and the need for additional help during the migration
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@73
# The sender, Phillip K Allen, addresses a group of recipients (John Lavorato-M, Mike Grigsby-D, Keith Holst-D, Frank Ermis-D, Steve South-D, Janie Tholt-D, Scott Neal-P, Hunter Shively-P, Tom Martin-P, and John Arnold-P) in a professional manner, mentioning their positions as "P" (probationary) and "D" (drafted) and referring to a file named "pallen.nsf". The email is dated 31 August 2000, and it is sent in the format of a business memo.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@74
# Phillip K Allen, from Enron, is sending a spreadsheet detailing their September Socal trades to Mark at Intelligence Press. The email does not specify whether the trades are for buying or selling.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@75
# Phillip Allen responds to Greg's message about his bike ride, expressing good luck and curiosity about his apartment and kids' return to school. Keith mentions that other than work, there is nothing significant happening in his life.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@76
# Phillip Allen is asking Cindy Long why Clog-4NNJEZ's security request has been denied. Allen mentions that he received this message and is curious about the reason behind the denial.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@77
# A message containing a spreadsheet detailing September Socal trades is received. The sender, Phillip Allen from Enron, does not specify whether the trades are for buying or selling.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@78
# Phillip Allen, from Enron, sends an email to Mark at Intelligence Press on August 29, 2000, at 05:38:00 PDT. The message is in plain text, 7-bit encoding, and is part of his note's folder. The email is addressed to Mark@intelligencepress.com. Phillip inquires about Mark's ability to log in to Enron Online and find deals from Southern California. He also promises to provide a list of physical deals done the previous day and the current day.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@79
# Phillip Allen requests Brenda's address to send her something.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@80
# This email is from Phillip K Allen and is addressed to multiple recipients, including Christopher F Calger, Jake Thomas, Frank W Vickers, Elliot Mainzer, Michael McDonald, David Parquet, Laird Dyer, Jim Buerkle, Jim Gilbert, Terry W Donovan, Jeff G Slaughter, Ed Clark, Tim Belden, Robert Badeer, Matt Motley, and Phillip K Allen. The email is titled "New Generation" and was sent on August 28, 2000, at 06:40:00 -0700 (PDT). It is a forwarded message from Kristian J Lande, originally sent on August
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@81
# The email is from Phillip Allen to Mark, providing a guest password for EnronOnline. Phillip tells Mark to install Shockwave using the instructions provided and suggests consulting Kathy Moore if there are any login issues. The email also mentions that Phillip has set up a composite page with Western Basis and cash prices to help Mark filter through the products, and that the Shockwave installer can be found within "About EnronOnline". Phillip hopes that Mark will find the site useful.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@82
# In an email dated August 28, 2000, Phillip Allen from Enron Corp. sent a spreadsheet to Mark from Intelligence Press. The spreadsheet contains end-of-day midmarket data for Southern California (SOCAL) basis and SOCAL/San Juan spreads. The data was collected during bidweek and shows the differences between anticipated and actual values. The email highlights some observations from the data, including the anticipated Socal/San Juan spreads and the perceived index values. The spreadsheet also indicates that Socal Gas Daily Swaps are trading at a premium. Phillip Allen suggests that Enron Online can help monitor the value of financial swaps against the index and spreads to other
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@83
# In the email, Phillip Allen informs Alan Comnes that Keith Holst has provided updated numbers, and Phillip is requesting Alan to contact him if he did not receive the updates. The email is dated Monday, April 30, 2001, at 7:04 PM PDT. The email is part of the Allen-P folder in Phillip's Outlook with the filename "pallen (Non-Privileged).pst."
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@84
# On August 25, 2000, at 6:32 a.m., Phillip Allen from Enron sent an email to Suzanne Nicholie, a recipient at Enron. The email was sent from Allen's personal email account, Phillip.Allen@enron.com, and was received by Suzanne.Nicholie@enron.com. The email was sent in response to a previous email discussing the need for a meeting to discuss the 2001 direct expense plan. Phillip requested more details about the plan or asked if Suzanne could email it to him before the meeting. He also asked what he needed to provide besides headcount. Phillip
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@85
# An email from Phillip Allen to Colleen Sullivan at Enron discusses adding Mike Grigsby to the distribution list for regulatory filing summaries. Phillip also inquires about Patti's well-being.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@86
# The email is from Phillip Allen to Brad McSherry, cc: John Lavorato and Hunter Shively, with additional cc:s to John Lavorato and Hunter Shively. Phillip proposes promoting Tori Kuykendall from Commercial Support Manager to Commercial Manager instead of converting her to an Associate. He also mentions Martin Cuilla's situation, suggesting they should be treated similarly to Tori. Phillip seeks confirmation on potential issues regarding this proposal and requests a response.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@87
# In this email, Phillip Allen requests that Bruce Ferrell stop by to set up his Reuters application. The email is part of a series of messages related to the setup of a trading application, as indicated by the "Evaluation for new trading application" subject line. The email is sent from Phillip Allen's account (X-Origin: Allen-P) and includes a reference to a specific folder where the email is being stored (X-Origin: Allen-P).
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@88
# An email from Phillip Allen to Lucy, dated August 25, 2000, discusses the progress of the rent roll spreadsheet. Phillip suggests several modifications to improve the spreadsheet's functionality. He recommends using a formula in column E to add the value in column C to column D, using the formula =c6+d6. Additionally, he advises Lucy to adjust the column width in column F and brings up the idea of aligning the database columns with the spreadsheet to the right. Phillip concludes the email by offering his assistance.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@89
# Phillip Allen, from ENRON, responds to an email with an attachment from Lucy Gonzalez. He suggests collaborating on a task that will be completed today.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@90
# A message is sent from Phillip K Allen to Ina Rangel, signed in with his name and the origin from Phillip_Allen_Dec2000. The message is an approval for a project, possibly related to the ENA Fileplan Project, and it is signed off with his name.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@91
# Phillip Allen from Enron sends an email to Lucy Gonzalez, addressing a
# previous email discussion and inquiring about the progress on creating
# spreadsheets. Phillip mentions needing to close the file before attaching to
# an email and expresses a desire to make progress on two files.
#
# ### Key Points:
# 1. **Previous Discussion**: Phillip refers to a prior email exchange.
# 2. **Progress on Spreadsheets**: Phillip asks about the status of creating
#    spreadsheets.
# 3. **File Closure**: Phillip needs to close the file before attaching it to
#    an email.
# 4. **
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@92
# The email from Phillip Allen (phillip.allen@enron.com) to Lucy at stagecoachmama@hotmail.com requests Lucy to open an Excel file and input the rents and names due for the current week. Lucy is then asked to email the file back.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@93
# The sender, Phillip Allen, requests that the recipient, stagecoachmama, open a specific spreadsheet to analyze whether it is more advantageous to be a small or medium commercial, LP-1. Phillip needs the last 12 months' usage data for the meter to complete the analysis. If the recipient has one year's worth of data, they can determine which option will be cheaper using the provided rates in the spreadsheet. Phillip suggests this is a good opportunity for the recipient to practice using Microsoft Excel.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@94
# Phillip Allen requests a table update from Alan Comnes due to a request from Steve Kean, who needs an update on a table prepared by Phillip. The request involves updating a power point presentation and providing a forward price curve for gas and power in California. Phillip asks to receive these documents by Monday afternoon.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@95
# Phillip Allen, from Enron, sends a message to Mac Hargrove at RSSMB with a research report on EOG. Allen provides calculations on gas sales, estimated and actual gas prices, and EPS recalculation based on these figures. He suggests a valuation of EOG based on gas prices and includes a comparison of their stock performance with crude prices. He also asks Mac to review numbers and provide reports on Calpine, Tosco, and SLB.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@96
# The email from "Lucy Gonzalez" to Phillip Allen at Enron discusses several issues:
#
# 1. Apartment-related problems: Lucy is dealing with ants in her apartment, needs to install a bulletin board for tenants, and has had to address overcrowding issues (#25) and complaints about unwanted guests (#28).
#
# 2. Lease violations: #28 is using inappropriate language, and #29 is complaining about #28's behavior.
#
# 3. Upcoming communication: Lucy plans to call Phillip tomorrow.
#
# The email is a follow-up to previous communications and is part of a series of
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@97
# This email is from Phillip Allen to pallen70@hotmail.com. It contains a summary of a daily report from 2000. The report includes details about transactions made on August 16th, 2000, such as an air conditioner purchase at Walmart, a fridge and stove purchase at Ralph's Appliance Center, and the cost of a fax machine for the office. The total cost of all transactions is $308.56, with an additional delivery charge and tax. The email concludes with a reminder to sign up for a free email service from MSN Hotmail.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@98
# A message from Phillip Allen at Enron to Phyllis Allen at Hotmail, dated August 20, 2000, at 10:38:00 AM. Phillip is forwarding a message from Lucy Gonzalez to Phyllis. Lucy requests Phillip to inform Wade to fix his van so he can get what he needs and mentions that Wade had to pay a fine, taking a lot of time away from their schedule. Phillip will email Lucy the next day.
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@99
# Phillip Allen, from Enron, responds to an email from Mac Hargrove regarding an email about exercising options with Smith Barney. Allen informs that Enron has an exclusive agreement with Paine Weber and is considering selling JDSU and buying SDLI. He also suggests looking at EOG as a play on rising oil and gas prices.
#
# ### Email Content in Summary:
#
# Phillip Allen, from Enron, reacts to a previous email about exercising options with Smith Barney. Allen clarifies that Enron has an exclusive agreement with Paine Weber and is considering selling JDSU and buying SDLI. He also recommends considering EOG as a potential investment

# %%
output_path = '/content/drive/MyDrive/emails_final1.csv'
data2.to_csv(output_path, index=False)

# %%
data2
# Out:
#                         file  \
# 0      allen-p/_sent_mail/1.
# 1     allen-p/_sent_mail/10.
# 2    allen-p/_sent_mail/100.
# 3   allen-p/_sent_mail/1000.
# 4   allen-p/_sent_mail/1001.
# ..                       ...
# 95   allen-p/_sent_mail/180.
# 96   allen-p/_sent_mail/181.
# 97   allen-p/_sent_mail/182.
# 98   allen-p/_sent_mail/183.
# 99   allen-p/_sent_mail/184.
#
#                                               message  \
# 0   Message-ID: <18782981.1075855378110.JavaMail.e...
# 1   Message-ID: <15464986.1075855378456.JavaMail.e...
# 2   Message-ID: <24216240.1075855687451.JavaMail.e...
# 3   Message-ID: <13505866.1075863688222.JavaMail.e...
# 4   Message-ID: <30922949.1075863688243.JavaMail.e...
# ..                                                ...
# 95  Message-ID: <29919154.1075855689201.JavaMail.e...
# 96  Message-ID: <4511963.1075855689223.JavaMail.ev...
# 97  Message-ID: <33111317.1075855689245.JavaMail.e...
# 98  Message-ID: <1665326.1075855689266.JavaMail.ev...
# 99  Message-ID: <4752513.1075855689288.JavaMail.ev...
#
#                                           resume_phi3  \
# 0   The email, sent by Phillip Allen to Tim Belden...
# 1   The purpose of this email, sent by Phillip K A...
# 2   The email, sent by Phillip Allen to Leah Van A...
# 3   The email, sent by Phillip Allen to Randall Ga...
# 4   The email, sent by Phillip Allen to Greg Piper...
# ..                                                ...
# 95  The email from Phillip Allen to Mac D. Hargrov...
# 96  The email, sent by Phillip Allen from Enron to...
# 97  This email, sent by Phillip Allen of Enron to ...
# 98  The email, sent by Phillip Allen to pallen70@h...
# 99  The email, sent by Phillip Allen of Enron and ...
#
#                                            resume_h2o  \
# 0   The email is a message from Phillip Allen to T...
# 1   The sender, Phillip Allen, suggests that inste...
# 2   The email from Phillip Allen to Leah Van Arsda...
# 3   Phillip Allen requests a schedule detailing th...
# 4   - Phillip Allen sends a message about a Tuesda...
# ..                                                ...
# 95  Phillip Allen, from Enron, sends a message to ...
# 96  The email from "Lucy Gonzalez" to Phillip Alle...
# 97  This email is from Phillip Allen to pallen70@h...
# 98  A message from Phillip Allen at Enron to Phyll...
# 99  Phillip Allen, from Enron, responds to an emai...
#
#                                         resume_phi3_2  \
# 0   L'email envoyé par Phillip Allen à Tim Belden ...
# 1   Dans un autre email, Phillip Allen propose à J...
# 2    Un troisième email adressé à Leah Van Arsdall...
# 3   Dans un email à Randall Gay (23 octobre 2000),...
# 4    Un autre message à Greg Piper fait suite à un...
# ..                                                ...
# 95  The email from Phillip Allen to Mac D. Hargrov...
# 96  The email, sent by Phillip Allen from Enron to...
# 97  This email, sent by Phillip Allen of Enron to ...
# 98  The email, sent by Phillip Allen to pallen70@h...
# 99  The email, sent by Phillip Allen of Enron on A...
#
#                                          resume_h2o_2  \
# 0   0 The email is from Phillip Allen to Tim Belde...
# 1   Phillip Allen suggests holding business meetin...
# 2   Phillip Allen sends a test email to Leah Van A...
# 3   Phillip Allen requests a detailed schedule wit...
# 4   Phillip Allen sends a message about a meeting ...
# ..                                                ...
# 95  Phillip Allen, from Enron, sends a message to ...
# 96  The email from Lucy Gonzalez to Phillip Allen ...
# 97  This email is from Phillip Allen to pallen70@h...
# 98  A message from Phillip Allen at Enron to Phyll...
# 99  Phillip Allen, from Enron, responds to an emai...
#
#                                                resume
# 0   Prévision partagée (14 mai 2001) – Phillip All...
# 1   Suggestion pour un voyage d'affaires (4 mai 20...
# 2   Test réussi (18 octobre 2000) – Phillip Allen ...
# 3   Demande de détails sur les salaires et niveaux...
# 4   Proposition de réunion (31 août 2000) – Philli...
# ..                                                ...
# 95  I think crude price are undervalued by the tun...
# 96  Summarize the following email by focusing on t...
# 97  "Lucy Gonzalez": "The a/c I bought today for #...
# 98  Summarize the following email by focusing on t...
# 99  I checked into exercising options with Smith B...
#
# [100 rows x 7 columns]

# %%
pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.6)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=2c1773c71bcd6146324f299bc8031c79eca72446cdb0b04bd4a417b39872c910
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
pip install bert-score
# Out:
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.46.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.26.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13

# %%
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from bert_score import score

# **Étape 5 : Évaluation avec ROUGE, BLEU et BERTScore**
rouge_scorer_tool = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
smoothie = SmoothingFunction().method4

# Liste des colonnes à évaluer par rapport à 'resume'
columns_to_evaluate = ['resume_phi3', 'resume_h2o', 'resume_phi3_2', 'resume_h2o_2']

# Dictionnaires pour stocker les scores
rouge_scores = {col: {'rouge1': [], 'rouge2': [], 'rougeL': []} for col in columns_to_evaluate}
bleu_scores = {col: [] for col in columns_to_evaluate}
bertscore_scores = {col: [] for col in columns_to_evaluate}  # For storing BERTScore

# Parcours des lignes du DataFrame
for i, row in data.iterrows():
    reference = row['resume']

    # Calcul des scores pour chaque colonne par rapport à 'resume'
    for col in columns_to_evaluate:
        candidate = row[col]

        # Calcul des scores ROUGE
        scores = rouge_scorer_tool.score(reference, candidate)
        rouge_scores[col]['rouge1'].append(scores['rouge1'].fmeasure)
        rouge_scores[col]['rouge2'].append(scores['rouge2'].fmeasure)
        rouge_scores[col]['rougeL'].append(scores['rougeL'].fmeasure)

        # Calcul des scores BLEU
        reference_tokens = reference.split()
        candidate_tokens = candidate.split()
        bleu_score = sentence_bleu([reference_tokens], candidate_tokens, smoothing_function=smoothie)
        bleu_scores[col].append(bleu_score)

        # Calcul des scores BERTScore
        P, R, F1 = score([candidate], [reference], lang='en')
        bertscore_scores[col].append(F1.item())

# Calcul des moyennes des scores ROUGE, BLEU et BERTScore pour chaque colonne
average_rouge_scores = {col: {metric: sum(scores) / len(scores) if scores else 0
                              for metric, scores in rouge_scores[col].items()}
                       for col in rouge_scores}

average_bleu_scores = {col: sum(scores) / len(scores) if scores else 0
                       for col, scores in bleu_scores.items()}

average_bertscore_scores = {col: sum(scores) / len(scores) if scores else 0
                            for col, scores in bertscore_scores.items()}

# Affichage des résultats
for col in columns_to_evaluate:
    print(f"Scores moyens ROUGE pour {col}:")
    print(f"  ROUGE-1: {average_rouge_scores[col]['rouge1']}")
    print(f"  ROUGE-2: {average_rouge_scores[col]['rouge2']}")
    print(f"  ROUGE-L: {average_rouge_scores[col]['rougeL']}")
    print(f"Score moyen BLEU pour {col}: {average_bleu_scores[col]}")
    print(f"Score moyen BERTScore pour {col}: {average_bertscore_scores[col]}")
    print("\n")

# Enregistrement des résultats dans un fichier
output_path = "path/to/output/file"  # Remplacer par le chemin de votre fichier de sortie
print(f"Les résultats ont été enregistrés dans {output_path}.")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Scores moyens ROUGE pour resume_phi3:
#   ROUGE-1: 0.19174042877389882
#   ROUGE-2: 0.05444469026867209
#   ROUGE-L: 0.12998370549260674
# Score moyen BLEU pour resume_phi3: 0.020929190265824796
# Score moyen BERTScore pour resume_phi3: 0.8172372645139694
#
#
# Scores moyens ROUGE pour resume_h2o:
#   ROUGE-1: 0.24834541067361487
#   ROUGE-2: 0.0931865986870522
#   ROUGE-L: 0.18012826021033554
# Score moyen BLEU pour resume_h2o: 0.03844031024479857
# Score moyen BERTScore pour resume_h2o: 0.8268438225984573
#
#
# Scores moyens ROUGE pour resume_phi3_2:
#   ROUGE-1: 0.2154632100643438
#   ROUGE-2: 0.053201035194293145
#   ROUGE-L: 0.14664846627891687
# Score moyen BLEU pour resume_phi3_2: 0.0256734295101145
# Score moyen BERTScore pour resume_phi3_2: 0.8201579874753953
#
#
# Scores moyens ROUGE pour resume_h2o_2:
#   ROUGE-1: 0.2100917209823792
#   ROUGE-2: 0.07621098839724227
#   ROUGE-L: 0.15629520232369232
# Score moyen BLEU pour resume_h2o_2: 0.028991323594741165
# Score moyen BERTScore pour resume_h2o_2: 0.8272171658277512
#
#
# Les résultats ont été enregistrés dans path/to/output/file.

# %% [markdown]
# # Rapport sur la Comparaison des Prompts et Analyse des Erreurs pour la Tâche de Résumé de Texte
#
# ## 1. Introduction
#
# L’objectif de ce projet est d’évaluer les performances de trois modèles de génération de texte (NVIDIA/Minitron-4B-Base, Microsoft/Phi-3-mini-128k-instruct, H2O-Danube3-4B-Chat) sur la tâche de résumé de texte. Deux formulations de prompts ont été utilisées pour chaque modèle :
#
# - **Prompt 1** : "Summarize the email in a concise paragraph."
# - **Prompt 2** : "Analyze the email and provide a detailed paragraph describing its purpose, key ideas, and recommendations."
#
# Les scores **ROUGE** et **BLEU** ont été calculés par rapport à un modèle de référence, Google/Pegasus-CNN-Dailymail, pour évaluer la qualité des résumés.
#
# ## 2. Résultats par Modèle et Prompt
#
# ### 2.1. Microsoft/Phi-3-mini-128k-instruct
#
# | Prompt   | ROUGE-1  | ROUGE-2  | ROUGE-L  | BLEU    |
# |----------|----------|----------|----------|---------|
# | Prompt 1 | 0.1917   | 0.0544   | 0.1299   | 0.0209  |
# | Prompt 2 | 0.2154   | 0.0532   | 0.1466   | 0.0257  |
#
# - **Analyse** :
#     - Les scores augmentent avec **Prompt 2** pour **ROUGE-1** (+12.4%) et **ROUGE-L** (+12.8%).
#     - Cela montre que le prompt détaillé améliore la richesse du résumé, même si **ROUGE-2** reste stable.
#     - **BLEU** montre également une légère amélioration.
#
# ### 2.2. H2O-Danube3-4B-Chat
#
# | Prompt   | ROUGE-1  | ROUGE-2  | ROUGE-L  | BLEU    |
# |----------|----------|----------|----------|---------|
# | Prompt 1 | 0.2100   | 0.0762   | 0.1563   | 0.0290  |
# | Prompt 2 | 0.2483   | 0.0932   | 0.1801   | 0.0384  |
#
# - **Analyse** :
#     - Les résultats sont maintenant inversés, montrant que **Prompt 1** est légèrement moins performant que **Prompt 2** pour **ROUGE-1** et **ROUGE-2**.
#     - Cependant, **ROUGE-L** reste plus faible avec **Prompt 1** comparé à **Prompt 2**, ce qui suggère que **Prompt 2** est plus adapté pour générer des résumés plus détaillés.
#
# ### 2.3. NVIDIA/Minitron-4B-Base
#
# | Prompt   | ROUGE-1  | ROUGE-2  | ROUGE-L  | BLEU    |
# |----------|----------|----------|----------|---------|
# | Prompt 1 | 0.1155   | 0.0072   | 0.0841   | 0.0057  |
# | Prompt 2 | 0.1269   | 0.0084   | 0.0868   | 0.0062  |
#
# - **Analyse** :
#     - **Prompt 2** donne de meilleurs scores pour **ROUGE-1** (0.1269 vs 0.1155) et **ROUGE-2** (0.0084 vs 0.0072) comparé à **Prompt 1**. Cela montre que **Prompt 2** génère des résumés plus pertinents en termes de correspondance avec le modèle de référence, particulièrement pour les éléments clés du texte.
#
#     - Le score **BLEU** est très faible dans les deux cas (0.0062 pour **Prompt 2** et 0.0057 pour **Prompt 1**), ce qui suggère que les résumés produits ne correspondent pas précisément au texte de référence au niveau des n-grammes, ce qui est typique pour des résumés très concis ou détaillés qui diffèrent structurellement du texte source.
#
#     - Le **ROUGE-L** est relativement faible également (0.0868 pour **Prompt 2** et 0.0841 pour **Prompt 1**), ce qui indique que les modèles ne parviennent pas à capturer parfaitement la structure longue du texte source, mais le score reste relativement similaire pour les deux prompts. Cela peut être dû à la difficulté de conserver la structure complète d'un texte plus long, même dans un résumé détaillé.
#
#     - Il est important de noter que ces résultats montrent que **NVIDIA/Minitron-4B-Base** a une capacité à générer des résumés cohérents, mais que les scores **BLEU** et **ROUGE-L** restent faibles en comparaison avec les autres modèles comme **H2O-Danube3-4B**, ce qui peut indiquer une incapacité à saisir les relations longues et complexes dans le texte.
# ### 2.4. stabilityai/stablelm-zephyr-3b
#     - le modèle stabilityai/stablelm-zephyr-3b a montré de bons résultats. Bien qu'il n'y ait pas de métriques d’évaluation détaillées dans ce rapport, ce modèle est performant et génère des résumés de qualité qui correspondent bien aux attentes de la tâche.
#
# ## 3. Comparaison des Meilleurs Prompts
#
# | Modèle              | Meilleur Prompt | ROUGE-1  | ROUGE-2  | ROUGE-L  | BLEU    |
# |---------------------|-----------------|----------|----------|----------|---------|
# | Microsoft/Phi-3     | Prompt 2        | 0.2154   | 0.0532   | 0.1466   | 0.0257  |
# | H2O-Danube3-4B      | Prompt 2        | 0.2483   | 0.0932   | 0.1801   | 0.0384  |
# | NVIDIA/Minitron-4B  | Prompt 2        | 0.1269   | 0.0084   | 0.0868   | 0.0062  |
#
# - **Observation générale** :
#     - **H2O-Danube3-4B** avec **Prompt 2** donne les meilleurs scores **ROUGE-1**, **ROUGE-2**, et **ROUGE-L**, avec un **BLEU** de 0.0384, ce qui en fait le modèle le plus performant dans cette comparaison.
#     - **Microsoft/Phi-3-mini-128k** obtient de meilleurs résultats avec **Prompt 2**, mais reste en dessous de H2O-Danube3-4B.
#     - **NVIDIA/Minitron-4B**, bien que performant, a un score **BLEU** plus faible, ce qui indique que la structure des résumés générés est moins conforme aux attentes des métriques basées sur des n-grammes.
#
# ## 4. Temps d’Exécution
#
# | Modèle               | Temps d'exécution |
# |----------------------|-------------------|
# | NVIDIA/Minitron-4B   | 2h10min           |
# | Microsoft/Phi-3-mini | 1h20min           |
# | H2O-Danube3-4B       | 1h40min           |
# | stablelm-zephyr-3b   | 30min           |
#
# - **Analyse** :
#     - **stabilityai/stablelm-zephyr-3b** est le plus rapide (1h20min) tout en offrant des performances solides avec **Prompt 2**.
#     - **H2O-Danube3-4B** et **Microsoft/Phi-3-mini** est légèrement plus lent mais fournit les meilleurs scores.
#     - **NVIDIA/Minitron-4B** (2h10min) est le modèle le plus lent, malgré des résultats moyens.
#
# ## 5. Analyse des Erreurs
#
# ### 5.1. Par Prompt
#
# - **Prompt 1** :
#     - Génère des résumés plus concis, mais manque parfois de détails critiques comme les recommandations ou idées secondaires.
#     - Peut conduire à des résumés plus proches du texte source, mais à un niveau de détail plus faible.
#
# - **Prompt 2** :
#     - Fournit des résumés détaillés mais inclut parfois des informations redondantes ou moins pertinentes.
#
# ### 5.2. Par Modèle
#
# - **Microsoft/Phi-3-mini** : Bonne capacité d’analyse avec **Prompt 2**, mais tendance à ajouter des informations implicites non présentes dans le texte source.
# - **H2O-Danube3-4B** : Résumés équilibrés et précis avec **Prompt 2**, bien qu'une légère perte de détail apparaisse avec **Prompt 1**.
# - **NVIDIA/Minitron-4B** : Temps d’exécution élevé avec des résumés parfois moins cohérents pour des textes complexes.
#
# ## 6. Conclusion
#
# Le modèle **H2O-Danube3-4B-Chat** avec **Prompt 2** s'est montré le plus performant, avec les meilleurs scores **ROUGE-1**, **ROUGE-2**, et **ROUGE-L**, mais avec un score **BLEU** modeste. Cependant, la complexité du texte et le choix du prompt jouent un rôle crucial dans l'amélioration des résultats. Les résultats montrent que les prompts plus détaillés (comme **Prompt 2**) peuvent parfois offrir une meilleure couverture des informations, mais aussi mener à des résumés moins précis dans certaines situations.
